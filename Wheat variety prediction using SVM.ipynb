# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/wheet-variety-prediction-svm-b2/sample_submission.csv
# /kaggle/input/wheet-variety-prediction-svm-b2/wheet_test.csv
# /kaggle/input/wheet-variety-prediction-svm-b2/wheet_train.csv

# %%
import matplotlib.pyplot as plt
test_data=pd.read_csv("/kaggle/input/wheet-variety-prediction-svm-b2/wheet_test.csv")
test_data
# Out:
#     ID   area  perimeter  compactness  kernelLength  kernelWidth  \
# 0    1  18.85      16.17       0.9056         6.152        3.806
# 1    2  11.34      12.87       0.8596         5.053        2.849
# 2    3  14.86      14.67       0.8676         5.678        3.258
# 3    4  12.67      13.32       0.8977         4.984        3.135
# 4    5  11.82      13.40       0.8274         5.314        2.777
# ..  ..    ...        ...          ...           ...          ...
# 65  66  15.11      14.54       0.8986         5.579        3.462
# 66  67  18.14      16.12       0.8772         6.059        3.563
# 67  68  11.21      13.13       0.8167         5.279        2.687
# 68  69  15.57      15.15       0.8527         5.920        3.231
# 69  70  13.16      13.55       0.9009         5.138        3.201
#
#     asymmetryCoefficient  kernelGrooveLength.
# 0                  2.843                6.200
# 1                  3.347                5.003
# ...

# %%
train_data=pd.read_csv("/kaggle/input/wheet-variety-prediction-svm-b2/wheet_train.csv")
train_data
# Out:
#       ID   area  perimeter  compactness  kernelLength  kernelWidth  \
# 0      1  18.59      16.05       0.9066         6.037        3.860
# 1      2  11.18      12.72       0.8680         5.009        2.810
# 2      3  15.99      14.89       0.9064         5.363        3.582
# 3      4  15.38      14.90       0.8706         5.884        3.268
# 4      5  19.15      16.45       0.8890         6.245        3.815
# ..   ...    ...        ...          ...           ...          ...
# 135  136  11.65      13.07       0.8575         5.108        2.850
# 136  137  18.27      16.09       0.8870         6.173        3.651
# 137  138  12.15      13.45       0.8443         5.417        2.837
# 138  139  16.16      15.33       0.8644         5.845        3.395
# 139  140  13.84      13.94       0.8955         5.324        3.379
#
#      asymmetryCoefficient  kernelGrooveLength.  Type
# 0                   6.001                5.877     2
# 1                   4.051                4.828     3
# ...

# %%
X = train_data.iloc[:,0:8].values
y = train_data.iloc[:,8].values
X
y
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.25,random_state=0)
X_train
# Out:
# array([[ 84.    ,  18.45  ,  16.12  ,   0.8921,   6.107 ,   3.769 ,
#           2.235 ,   5.794 ],
#        [ 61.    ,  18.94  ,  16.49  ,   0.875 ,   6.445 ,   3.639 ,
#           5.064 ,   6.362 ],
#        [107.    ,  12.89  ,  13.77  ,   0.8541,   5.495 ,   3.026 ,
#           6.185 ,   5.316 ],
#        [ 90.    ,  18.89  ,  16.23  ,   0.9008,   6.227 ,   3.769 ,
#           3.639 ,   5.966 ],
#        [ 79.    ,  16.12  ,  15.    ,   0.9   ,   5.709 ,   3.485 ,
#           2.27  ,   5.443 ],
#        [ 45.    ,  14.59  ,  14.28  ,   0.8993,   5.351 ,   3.333 ,
#           4.185 ,   4.781 ],
#        [ 31.    ,  14.11  ,  14.26  ,   0.8722,   5.52  ,   3.168 ,
#           2.688 ,   5.219 ],
#        [ 63.    ,  12.8   ,  13.47  ,   0.886 ,   5.16  ,   3.126 ,
#           4.873 ,   4.914 ],
#        [122.    ,  16.19  ,  15.16  ,   0.8849,   5.833 ,   3.421 ,
#           0.903 ,   5.307 ],
#        [115.    ,  13.74  ,  14.05  ,   0.8744,   5.482 ,   3.114 ,
# ...

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear',gamma='auto', C=2)
classifier.fit(X_train, y_train)
# Out:
# SVC(C=2, gamma='auto', kernel='linear')

# %%
y_pred = classifier.predict(X_test)
y_pred
newid=X_test[:,0]

# %%
output=pd.DataFrame({'ID':newid,'Type':y_pred})
output.to_csv('submission.csv',index=False)
output
# Out:
#        ID  Type
# 0    46.0     1
# 1    60.0     3
# 2     8.0     2
# 3    51.0     3
# 4    93.0     1
# 5    28.0     1
# 6   132.0     3
# 7   138.0     3
# 8   123.0     3
# 9     9.0     3
# 10  112.0     1
# 11   17.0     3
# 12   64.0     3
# 13   77.0     2
# 14  124.0     2
# 15   98.0     3
# 16  105.0     2
# 17  111.0     1
# 18   34.0     3
# 19   92.0     1
# 20   91.0     3
# 21   23.0     3
# 22  103.0     3
# 23   25.0     1
# 24    3.0     1
# 25   52.0     1
# 26   27.0     2
# 27   72.0     3
# 28   19.0     1
# 29   11.0     3
# 30   57.0     2
# 31   44.0     1
# 32  110.0     1
# 33   49.0     3
# 34  108.0     1
